# %%
import urllib3
import requests
from bs4 import BeautifulSoup
'''
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive 


# ?Section to authenticate into google drive and have it scrape contents of a folder?

ga = GoogleAuth()
ga.CommandLineAuth()  # This line in your code currently calls LocalWebserverAuth()
drive = GoogleDrive(self.ga)
# etc.
'''
# Designate source
print("Enter URL to be scraped")
url = input()

# Visit site
response = requests.get(url)

# Soupify
soup = BeautifulSoup(response.content)

# Save page contents as a .html file
with open ('scraped.html','w') as outfile:
    outfile.write(str(soup))
# Read page from the .html file
with open('scraped.html','r') as infile:
    page = infile.read()
soup = BeautifulSoup(page,'html.parser')
soup.prettify()

# Display HTML contents
print(soup)
# Out:
# Enter URL to be scraped
# https://www.serebii.net/anime/characters/ash.shtml
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>Ash Ketchum - Anime Character Biography - Serebii.net</title>
# <meta content="no" http-equiv="imagetoolbar"/>
# <link href="/style/layout.css" rel="stylesheet" type="text/css"/>
# <meta content="width=device-width,initial-scale=1" id="viewport-meta" name="viewport"/>
# <script type="text/javascript">
#
# 	var viewport_meta = document.getElementById('viewport-meta');
#
# 	var viewport_timer;
#
#
#
# 	// these body*Class are reused in the lbar mobile menu
#
# 	function bodyAddClass(className){
#
# 		if(document.body) document.body.classList.add(className);
#
# 	}
#
# 	function bodyRemoveClass(className){
#
# 		if(document.body) document.body.className = document.body.className.replace(className,"");
#
# 	}
#
#
#
# 	function viewport_set() {
#
# 		// Define our viewport meta values
#
# 		var viewports = {
#
# 			default: viewport_meta.getAttribute('content'),
#
# ...

# %%
# Empty list
terms_of_interest = []
# Set value for exiting the loop and filling the list
user_described_term = "blank"
# Build list
print("Enter terms of interest (type and enter \"Done\" to complete):")
while user_described_term != "done":
    list_length = str(len(terms_of_interest))
    print("Term " + list_length+":")
    user_described_term = input().lower()
    while (user_described_term == "") or (user_described_term.isspace() == True):
        print("Please provide a name for Term " + list_length+":")
        user_described_term = input().lower()        
    terms_of_interest.append(user_described_term)
del terms_of_interest[-1]
for i in terms_of_interest:
    open('newfile','w').writelines(line for line in soup if terms_of_interest[i] in line)
'''
# Empty list
scrape_fields = []
# Set value for exiting the loop and filling the list
user_described_field = "blank"

# Build list
print("Name your fields (type and enter \"Done\" to complete):")
while user_described_field != "done":
    list_length = str(len(scrape_fields))
    print("Name Field " + list_length)
    user_described_field = input().lower()
    while (user_described_field == "") or (user_described_field.isspace() == True):
        print("Please provide Name Field " + list_length)
        user_described_field = input().lower()        
    scrape_fields.append(user_described_field)
del scrape_fields[-1]

# Loop through list of fields and assign html field
for i in scrape_fields:
    print("Identify the tag for " + str(scrape_fields[i]))
    scrape_fields[i]= soup.findAll(input())
    scrape_fields[i] = list(map(lambda x: x.text,Type))
    
print(scrape_fields)
'''
# Out:
# Enter terms of interest (type and enter "Done" to complete):
# Term 0:
# Ash's
# Term 1:
# done
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-82015e2cb3e0> in <module>
#      15 del terms_of_interest[-1]
#      16 for i in terms_of_interest:
# ---> 17     open('newfile','w').writelines(line for line in soup if terms_of_interest[i] in line)
#      18 '''
#      19 # Empty list
#
# <ipython-input-2-82015e2cb3e0> in <genexpr>(.0)
#      15 del terms_of_interest[-1]
#      16 for i in terms_of_interest:
# ---> 17     open('newfile','w').writelines(line for line in soup if terms_of_interest[i] in line)
#      18 '''
#      19 # Empty list
#
# TypeError: list indices must be integers or slices, not str

# %%
# Separating time
print("Enter the tag:")
input_class = input()
print("\n"+"class:")
input_tag = input()
print("\n"+"and attribute:")
input_attribute = input()
Type = soup.findAll(input_class, {input_tag: input_attribute})
Type = list(map(lambda x: x.text,Type))

'''
SubType = soup.findAll('h3')
SubType = list(map(lambda x: x.text,SubType))
Item = soup.findAll('h4')
Item = list(map(lambda x: x.text,Item))
Description = soup.findAll('p')
Description = list(map(lambda x: x.text,Description))
Size = soup.findAll('div')
Size = list(map(lambda x: x.text,Size))
Price = soup.findAll('/span' '/div')
Price = list(map(lambda x: x.text,Price))

# Write data to file
data = list(zip(Type, SubType, Item, Description, Size, Price))
with open('LaRosasMenu.txt','w') as outfile:
    for d in data:
        record = '\t'.join(d)+'\n'
        outfile.write(record)
'''

print(Type)

# %%
"tag", {"class": "attribute"}
<div class="product_price">

# %%
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
import os

# If modifying these scopes, delete the file token.pickle.
SCOPES = ['https://drive.google.com/drive/folders/1DF6uxLPo2npvjgmOxcsNnZev9LTSDQ7e']

def main():
    """Shows basic usage of the Drive v3 API.
    Prints the names and ids of the first 10 files the user has access to.
    """
    creds = None
    # The file token.pickle stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first
    # time.
    if os.path.exists('token.pickle'):
        with open('token.pickle', 'rb') as token:
            creds = pickle.load(token)
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
        with open('token.pickle', 'wb') as token:
            pickle.dump(creds, token)

    service = build('drive', 'v3', credentials=creds)

    # Call the Drive v3 API
    results = service.files().list(
        pageSize=10, fields="nextPageToken, files(id, name)").execute()
    items = results.get('files', [])

    if not items:
        print('No files found.')
    else:
        print('Files:')
        for item in items:
            print(u'{0} ({1})'.format(item['name'], item['id']))

if __name__ == '__main__':
    main()
